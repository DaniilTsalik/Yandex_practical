# %%
! gdown --id 1zCLVF7juIAD5hV-j3mrATkZq2XhCE88s
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1zCLVF7juIAD5hV-j3mrATkZq2XhCE88s
# To: /content/hr_analitics.zip
# 100% 302k/302k [00:00<00:00, 75.9MB/s]

# %%
! unzip /content/hr_analitics.zip
# Out:
# Archive:  /content/hr_analitics.zip
#   inflating: aug_test.csv
#   inflating: aug_train.csv
#   inflating: sample_submission.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/aug_train.csv')

# %%
df.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %%
df['target'].unique()
# Out:
# array([1., 0.])

# %%
df['gender'] = df['gender'].replace('Other','no_info' ).fillna('no_info')

# %%
df['city'].duplicated().sum()
# Out:
# 19035

# %%
t = df.groupby('company_size', dropna=False)['target'].agg(['sum'])

# %%
t.columns
# Out:
# Index(['sum'], dtype='object')

# %%
t.plot(kind='bar')

# %%
df['city_development_index_group_custom'] = pd.cut(df['city_development_index'],
                                                   [-float('inf'),0,0.1,0.2,0.5,float('inf')])

# %%
x = (1,2,3)


y = ['abcde', 'thhrthtr','gdfhh']
print(y, flush=True)
# Out:
# ['abcde', 'thhrthtr', 'gdfhh']
